# %% [markdown]
# ### Perform EDA on the Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_final_train = pd.read_csv('../data/final_train.csv',index_col=0)

# %%
df_feature = pd.read_csv('../data/feature.csv',index_col=0)

# %%
df_feature.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  bedroomabvgr  bsmtfinsf1  bsmtfinsf2  \
# 0       856       854          0             3         706           0
# 1      1262         0          0             3         978           0
# 2       920       866          0             3         486           0
# 3       961       756          0             3         216           0
# 4      1145      1053          0             4         655           0
#
#    bsmtfullbath  bsmthalfbath  bsmtunfsf  enclosedporch    ...      \
# 0             1             0        150              0    ...
# 1             0             1        284              0    ...
# 2             1             0        434              0    ...
# 3             1             0        540            272    ...
# 4             1             0        490              0    ...
#
#    masvnrtype  mszoning  neighborhood  paveddrive  roofmatl  roofstyle  \
# 0     BrkFace        RL       CollgCr           Y   CompShg      Gable
# 1        None        RL       Veenker           Y   CompShg      Gable
# 2     BrkFace        RL       CollgCr           Y   CompShg      Gable
# 3        None        RL       Crawfor           Y   CompShg      Gable
# 4     BrkFace        RL       NoRidge           Y   CompShg      Gable
#
#    salecondition  saletype  street  utilities
# 0         Normal        WD    Pave     AllPub
# 1         Normal        WD    Pave     AllPub
# 2         Normal        WD    Pave     AllPub
# 3        Abnorml        WD    Pave     AllPub
# 4         Normal        WD    Pave     AllPub
#
# [5 rows x 77 columns]

# %%
feature_info = []
for col in df_final_train.columns:
    n_unique = len(df_final_train[col].unique())
    feature_info.append({'feature':col, 'n_unique': n_unique, 'datatype':df_final_train[col].dtype})
feature_info_df = pd.DataFrame(feature_info)

# %%
feature_info_df[(feature_info_df.datatype == 'object')]
# Out:
#    datatype        feature  n_unique
# 37   object          alley         2
# 38   object       bldgtype         5
# 39   object       bsmtcond         4
# 40   object   bsmtexposure         4
# 41   object   bsmtfintype1         6
# 42   object   bsmtfintype2         6
# 43   object       bsmtqual         4
# 44   object     centralair         2
# 45   object     condition1         9
# 46   object     condition2         8
# 47   object     electrical         5
# 48   object      extercond         5
# 49   object    exterior1st        15
# 50   object    exterior2nd        16
# 51   object      exterqual         4
# 52   object          fence         4
# 53   object    fireplacequ         5
# 54   object     foundation         6
# 55   object     functional         7
# 56   object     garagecond         5
# 57   object   garagefinish         3
# 58   object     garagequal         5
# 59   object     garagetype         6
# 60   object        heating         6
# 61   object      heatingqc         5
# 62   object     housestyle         8
# 63   object    kitchenqual         4
# 64   object    landcontour         4
# 65   object      landslope         3
# 66   object      lotconfig         5
# 67   object       lotshape         4
# 68   object     masvnrtype         4
# 69   object       mszoning         5
# 70   object   neighborhood        25
# 71   object     paveddrive         3
# 72   object       roofmatl         8
# 73   object      roofstyle         6
# 74   object  salecondition         6
# 75   object       saletype         9
# 76   object         street         2
# 77   object      utilities         2

# %%
corr_matrix = df_final_train.corr()
corr_matrix["saleprice"].sort_values(ascending = False)
# Out:
# saleprice        1.000000
# overallqual      0.790982
# grlivarea        0.708624
# garagecars       0.640409
# garagearea       0.623431
# totalbsmtsf      0.613581
# 1stFlrSF         0.605852
# fullbath         0.560664
# totrmsabvgrd     0.533723
# yearbuilt        0.522897
# garageyrblt      0.508043
# yearremodadd     0.507101
# masvnrarea       0.478854
# fireplaces       0.466929
# bsmtfinsf1       0.386420
# lotfrontage      0.334901
# wooddecksf       0.324413
# 2ndFlrSF         0.319334
# openporchsf      0.315856
# halfbath         0.284108
# lotarea          0.263843
# bsmtfullbath     0.227122
# bsmtunfsf        0.214479
# bedroomabvgr     0.168213
# screenporch      0.111447
# poolarea         0.092404
# mosold           0.046432
# 3SsnPorch        0.044584
# bsmtfinsf2      -0.011378
# bsmthalfbath    -0.016844
# miscval         -0.021190
# lowqualfinsf    -0.025606
# yrsold          -0.028923
# overallcond     -0.077856
# mssubclass      -0.084284
# enclosedporch   -0.128578
# kitchenabvgr    -0.135907
# Name: saleprice, dtype: float64

# %%
f, ax = plt.subplots(figsize=(22,12))
sns.heatmap(df_final_train.corr(),cmap = 'coolwarm')

# %%
sns.set_style('darkgrid')
g = sns.FacetGrid(df_final_train,hue="overallqual",palette='coolwarm',size=6,aspect=2)
g = g.map(plt.hist,'saleprice',bins=20,alpha=0.7)
plt.legend()
plt.xlabel('overallqual')
# Out:
# Text(0.5,6.8,'overallqual')

# %%
sns.jointplot(x='overallqual',y='saleprice',data=df_final_train)

# %% [markdown]
# **From Above Joint Plot we can determine that greater the Overall quality higher is the Sale Price & most property are of Overall Quality 5 & 6 **

# %%
sns.swarmplot(x='kitchenqual',y='saleprice',data=df_final_train)

# %%
sns.distplot(df_final_train['saleprice'])

# %%
plt.figure(figsize=(24,12))
sns.countplot(x='neighborhood',hue='kitchenqual',data=df_final_train,palette='Set1')

# %%
plt.figure(figsize=(24,12))
sns.lmplot(y='grlivarea',x='saleprice',data=df_final_train,hue='exterqual',
           col='alley',palette='Set1')

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x='garagefinish',y='saleprice',data=df_final_train,palette='rainbow')

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x='exterqual',y='saleprice',data=df_final_train,palette='rainbow',hue="kitchenqual")

# %% [markdown]
# **From Above plot we can determine that better Kitchen Quality & External Quality has higher SalePrice**

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x='housestyle',y='saleprice',data=df_final_train,palette='rainbow')

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x='mszoning',y='saleprice',data=df_final_train,palette='rainbow')

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x='roofmatl',y='saleprice',data=df_final_train,palette='rainbow')

# %% [markdown]
# **From Above we can determine RoofMaterial with Wood Shingle has higher SalePrice**
#
# ### Perform PCA

# %%
from sklearn.decomposition import PCA

# %%
pca_df = df_feature.select_dtypes(exclude=['object'])

# %%
pca = PCA()
pca.fit(pca_df)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
plt.plot(pca.explained_variance_ratio_)

# %%
pca_df.corr()
# Out:
#                1stFlrSF  2ndFlrSF  3SsnPorch  bedroomabvgr  bsmtfinsf1  \
# 1stFlrSF       1.000000 -0.202646   0.056104      0.127401    0.445863
# 2ndFlrSF      -0.202646  1.000000  -0.024358      0.502901   -0.137079
# 3SsnPorch      0.056104 -0.024358   1.000000     -0.024478    0.026451
# bedroomabvgr   0.127401  0.502901  -0.024478      1.000000   -0.107355
# bsmtfinsf2        -0.067759  0.031706
# bsmtfullbath       0.119470  0.067049
# bsmthalfbath      -0.012337 -0.046524
# bsmtunfsf          0.181133 -0.041258
# enclosedporch     -0.193919 -0.009916
# fireplaces         0.112581 -0.024096
# fullbath           0.439046 -0.019669
# garagearea         0.371600 -0.027378
# garagecars         0.420622 -0.039117
# garageyrblt        0.604353 -0.009877
# grlivarea          0.287389 -0.036526
# halfbath           0.183331 -0.010269
# kitchenabvgr      -0.149598  0.031687
# lotarea            0.013788 -0.014261
# lotfrontage        0.082746  0.006768
# lowqualfinsf      -0.062419 -0.028921
# masvnrarea         0.180317 -0.009878
# miscval           -0.010286  0.004906
# mosold             0.021490 -0.145721
# mssubclass         0.040581 -0.021407
# openporchsf        0.226298 -0.057619
# overallcond        0.073741  0.043950
# overallqual        0.550684 -0.027347
# poolarea           0.005829 -0.059689
# screenporch       -0.038740  0.010694
# totalbsmtsf        0.291066 -0.014969
# totrmsabvgrd       0.191740 -0.034516
# wooddecksf         0.205726  0.022270
# yearbuilt          0.592855 -0.013618
# yearremodadd       1.000000  0.035743
# yrsold             0.035743  1.000000
#
# [36 rows x 36 columns]

# %%
pca = PCA(2)
pca.fit(pca_df)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
pca_df.shape
# Out:
# (1460, 36)

# %%
ames_pca_df = pd.DataFrame(pca.transform(pca_df), 
                               columns=['Dim 1', 'Dim 2'],
                               index=pca_df.index)

# %%
ames_pca_df.shape
# Out:
# (1460, 2)

# %%
pca.components_
# Out:
# array([[ 1.16476384e-02,  2.24445578e-03,  6.01414964e-05,
#          9.81259701e-06,  9.82485404e-03,  1.79654289e-03,
#          8.24575210e-06,  1.14862625e-06, -1.01871301e-04,
#         -1.12976296e-04,  1.75673448e-05,  7.00023590e-06,
#          3.88355032e-03,  1.16574704e-05,  1.12884102e-05,
#          1.39155686e-02,  7.33455509e-07, -3.91507252e-07,
#          9.99702432e-01,  6.78080133e-04,  2.34744152e-05,
#          1.89321402e-03,  1.89413373e-03,  3.41232126e-07,
#         -5.92684370e-04,  5.65955157e-04, -6.54215010e-07,
#          1.48026029e-05,  3.13711313e-04,  2.42009838e-04,
#          1.15195256e-02,  3.10875653e-05,  2.16117029e-03,
#          4.49400321e-05,  2.96892925e-05, -1.90090380e-06],
#        [ 4.22230219e-01,  1.92099681e-01,  1.39980719e-03,
#          3.70132007e-04,  2.39258949e-01, -1.00133866e-02,
#          1.03223850e-04, -1.06313203e-05,  2.52908857e-01,
#         -4.73243555e-03,  3.78620703e-04,  4.43920505e-04,
#          1.73471902e-01,  5.78059074e-04,  1.40906163e-02,
#          6.17302256e-01,  1.61009428e-04,  1.20130072e-05,
#         -2.27629539e-02,  1.11859404e-02,  2.97235673e-03,
#          1.19075807e-01, -3.78729830e-02,  1.64145778e-04,
#         -3.05823454e-03,  3.08727301e-02, -2.49326153e-04,
#          1.31981703e-03,  8.55820985e-03,  7.44160063e-03,
#          4.82154420e-01,  1.47951014e-03,  4.40040457e-02,
#          1.58386084e-02,  1.05962262e-02, -5.51873993e-05]])
